# %% [markdown]
# <a href="https://colab.research.google.com/github/menakinako/Iris-Flower-data-analysis/blob/main/Iris_Flower_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Iris Flower Exploratory Data Analysis

# %% [markdown]
# The Iris flower data set or Fisher’s Iris data set is one of the most famous multivariate data set used for testing various Machine Learning Algorithms.
#
#  The Iris flower data set was introduced by the British statistician and biologist Ronald Fisher in his 1936 paper. Because Edgar Anderson gathered the data to quantify the morphologic variation of Iris blooms of three related species, it is also referred to as Anderson's Iris data set.
#
# The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8936103c-f0bb-4b06-9d86-a168216c5a4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8936103c-f0bb-4b06-9d86-a168216c5a4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IRIS.csv to IRIS.csv

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))
ifd.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# There is no Null values

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# 1. First four columns are numerical float type.
# 2. Last species column is categorical type
# 3. There is no Null entries

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# The standard deviation of petal length is more as compared to others hence we can use it to understand the difference in features.

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd.groupby('species').agg(['min','max','mean'])
# Out:
#                 sepal_length              ... petal_width
#                          min  max   mean  ...         min  max   mean
# species                                   ...
# Iris-setosa              4.3  5.8  5.006  ...         0.1  0.6  0.244
# Iris-versicolor          4.9  7.0  5.936  ...         1.0  1.8  1.326
# Iris-virginica           4.9  7.9  6.588  ...         1.4  2.5  2.026
#
# [3 rows x 12 columns]

# %% [markdown]
# 1. Sepal length, petal width and petal length of iris-virginica is maximum as compared to others whereas sepal width of iris-setosa is maximum.

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd[ifd.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %% [markdown]
# There are 3 duplicates, therefore we must check whether each species data set is balanced in number's or not.

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

ifd.shape
# Out:
# (150, 5)

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

sns.countplot(ifd.species)

# %% [markdown]
# There are three species of each 50 sample

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

plt.figure(figsize=(8,7))
sns.boxplot('species','sepal_length',data=ifd)

plt.figure(figsize=(8,7))
sns.boxplot('species','sepal_width',data=ifd)
            
plt.figure(figsize=(8,7))
sns.boxplot('species','petal_length',data=ifd)
            
plt.figure(figsize=(8,7))
sns.boxplot('species','petal_width',data=ifd)

# %% [markdown]
# 1. Setosa is having smaller feature and less distributed
# 2. Versicolor is distributed in a average manner and average features
# 3. Virginica is highly distributed with large no .of values and features

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

plt.figure(figsize=(8,6))
sns.violinplot('species','sepal_length',data=ifd)

plt.figure(figsize=(8,6))
sns.violinplot('species','sepal_width',data=ifd)

plt.figure(figsize=(8,6))
sns.violinplot('species','petal_length',data=ifd)

plt.figure(figsize=(8,6))
sns.violinplot('species','petal_width',data=ifd)

# %% [markdown]
# 1. Setosa is having less distribution and density in case of petal length & width.
#
# 2. Versicolor is distributed in a average manner and average features in case of petal length & width.
#
# 3. Virginica is highly distributed with large no .of values and features in case of sepal length & width.
#
# 4. High density values are depicting the mean/median values, for example: Iris Setosa has highest density at 5.0 cm ( sepal length feature) which is also the median value(5.0) as per the table.

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

plt.figure(figsize=(10,8))
m = pd.melt(ifd,'species',var_name='measurement')
sns.barplot('measurement','value',hue='species',data=m)

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

sns.pairplot(ifd,hue='species')

# %% [markdown]
#  Bivariate Analysis:
#
# 1. High co relation between petal length and width columns.
# 2. Setosa has both low petal length and width
# 3. Versicolor has both average petal length and width
# 4. Virginica has both high petal length and width.
# 5. Sepal width for setosa is high and length is low.
# 6. Versicolor have average values for for sepal dimensions.
# 7. Virginica has small width but large sepal length

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

sns.distplot(ifd.sepal_length)

sns.distplot(ifd.sepal_width)

sns.distplot(ifd.petal_length)

sns.distplot(ifd.petal_width)

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

sns.heatmap(ifd.corr(),annot=True)

# %% [markdown]
#   Checking Correlation:
#
# 1. Sepal Length and Sepal Width features are slightly correlated with each other.
#
# 2. Petal Length and Petal Width are highly Correlated -- 0.96.
#
# 3. Petal Length and Sepal Length having strong Correlation -- 0.87.
#
# 4. Sepal Length and Petal Width have also storng Correlation -- 0.82.

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
ifd = pd.read_csv(io.BytesIO(uploaded['IRIS.csv']))

fig, axes = plt.subplots(2, 2, figsize=(11,11))
axes[0,0].set_title("Scatter Chart of Sepal Length vs Sepal Width")
axes[0,0].scatter(ifd.sepal_length,ifd.sepal_width)
axes[0,1].set_title("Scatter Chart of Petal Length vs Petal Width")
axes[0,1].scatter(ifd.petal_length,ifd.petal_width)
axes[1,0].set_title("Scatter Chart of Sepal Length vs Petal Width")
axes[1,0].scatter(ifd.sepal_length,ifd.petal_width)
axes[1,1].set_title("Scatter Chart of Petal Length vs Sepal Width")
axes[1,1].scatter(ifd.petal_length,ifd.sepal_width)

# %% [markdown]
# ## Summary
#
# As mentioned above, the Iris Dataset is Composed of 5 features (4 Numerical, 1 Categorical), Numerical features are Sepal Width, Sepal Length, Petal Width, Petal Length.and Cetegorical features are Species. Below are the Some Insights analyzed in data
#
# 1. Iris Setosa have very Narrow Petal Width and Short Petal and Sepal Lenght, but very wide Sepal Width.
# 2. Iris virginica are just opposite of Iris Setosa, have Wide Petal, and Long Petal and Sepal Length, and Sepal Width are moderate.
# 3. Iris versicolor's Sepal and Petals Length and Width are Median of Both Iris Setosa and Iris virginica
# 4. The Distribution of Sepal Length and Sepal Width are Normal, but the distributioin of Petal width and Petal Lenght are kind of Bi Modal. After analyzing, why it is bi modal, I came to a conclusion that, it is due to the small petal width and length of iris Setosa
# 5. Petal Length and Petal Width are highly Correlated -- 0.96
# 6. Petal Length and Sepal Length having strong Correlation -- 0.87
# 7. Sepal Length and Petal Width have also storng Correlation -- 0.82
